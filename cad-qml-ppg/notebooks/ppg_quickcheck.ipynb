# %%
import neurokit2 as nk
import numpy as np
import matplotlib.pyplot as plt

ppg = nk.ppg_simulate(duration=20, sampling_rate=200)
signals, info = nk.ppg_process(ppg, sampling_rate=200)
nk.ppg_plot(signals)
plt.show()
# Out:
# d:\Projects\P1_QML_CVD\.qml_cad\Lib\site-packages\neurokit2\ppg\ppg_plot.py:67: NeuroKitWarning: 'info' dict not provided. Some information might be missing. Sampling rate will be set to 1000 Hz.
#   warn(
